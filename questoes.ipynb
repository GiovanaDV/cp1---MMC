# %% [markdown]
# CP1 - 2 SEMESTRE MMC
# Giovana Dias Valentini RM562390

# %% [markdown]
# Pergunta 1 (2 pontos) - Escolher 1 propriedade de cada um dessas seções:

# %% [markdown]
# Arithmetic Operations
# ![Captura de tela 2025-08-27 102914.png](attachment:1cd8f2fa-108d-47e7-a17e-6f3b9e883156.png)
#
# Exponent Properties
# ![Captura de tela 2025-08-27 103142.png](attachment:13d0eed6-fc1b-4c0f-afed-ccbc6043a2e8.png)
#
# Properties of Radicals
# ![Captura de tela 2025-08-27 103211.png](attachment:402ceb26-db91-4357-8361-42790e57de08.png)
#
# Properties of Inequalities
# ![Captura de tela 2025-08-27 103249.png](attachment:6c4ec8be-1ace-45cb-84a0-63650b203321.png)
#
# Logarithm Properties
# ![Captura de tela 2025-08-27 103342.png](attachment:ced6fb36-8b3e-456f-ab17-6a879d345432.png)

# %% [markdown]
# Pergunta 2 (2 pontos) Sobre o mesmo PDF, escolher 3 erros algébricos
# comuns (Common Algebraic Errors) e verificá-los utilizando Python.

# %% [markdown]
# ![Captura de tela 2025-08-27 114806.png](attachment:f37db692-6acb-4dc1-a08b-3bdc92f61c8b.png)

# %% [markdown]
#  Pergunta 3 (3 pontos) - Verifique essas propriedades utilizando numpy
# (numérico). Gere vetores numéricos e verifique as igualdades do slide
# anterior.
# Definir vetores arbitrariamente. Podem ser aleatórios.
#
# ![Captura de tela 2025-08-28 142341.png](attachment:08356ceb-9d29-4688-9dc7-0ba1f60657e0.png)
